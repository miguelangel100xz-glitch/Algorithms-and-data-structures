# %%
def dfs_recursivo(grafo, nodo, visitados=None):
    if visitados is None:
        visitados = set()

    visitados.add(nodo)
    print(nodo, end=" ")


    for vecino in grafo[nodo]:
        if vecino not in visitados:
            dfs_recursivo(grafo, vecino, visitados)

    return visitados



def dfs_iterativo(grafo, inicio):
    visitados = set()
    pila = [inicio]

    while pila:
        nodo = pila.pop()
        if nodo not in visitados:
            visitados.add(nodo)
            print(nodo, end=" ")

            for vecino in reversed(grafo[nodo]):
                if vecino not in visitados:
                    pila.append(vecino)

    return visitados


grafo = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}

print("recursivo")
dfs_recursivo(grafo,'A')


print("\n iterativo")
dfs_iterativo(grafo, 'A')
# Out:
# recursivo
# A B D E F C
#  iterativo
# A B D E F C
# {'A', 'B', 'C', 'D', 'E', 'F'}

# %%
grafo = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}


def dfs_dirigido(grafo, nodo, visitados=None):
    if visitados is None:
        visitados = set()

    visitados.add(nodo)
    print(nodo, end=" ")

    for vecino in grafo.get(nodo, []):
        if vecino not in visitados:
            dfs_dirigido(grafo, vecino, visitados)

    return visitados


def tiene_ciclo(grafo):
    visitados = set()
    en_pila = set()

    def dfs(nodo):
        visitados.add(nodo)
        en_pila.add(nodo)  # Corrected from en_pila(nodo)

        for vecino in grafo.get(nodo, []):
            if vecino not in visitados:
                if dfs(vecino):
                    return True
            elif vecino in en_pila:
                return True

        en_pila.remove(nodo)
        return False

    # These lines were incorrectly unindented, causing SyntaxError
    for nodo in grafo:
        if nodo not in visitados:
            if dfs(nodo):
                return True
    return False



def orden_topologico(grafo):
    visitados = set()
    resultados = []

    def dfs(nodo):
        visitados.add(nodo)
        for vecino in grafo.get(nodo, []):
            if vecino not in visitados:
                dfs(vecino)
        resultados.append(nodo) # Corrected from resultado.append(nodo)


    for nodo in grafo:
        if nodo not in visitados:
            dfs(nodo)

    return resultados[::-1]


print("dfs desde A:")
dfs_dirigido(grafo, 'A')
print("\n tiene ciclo: ", tiene_ciclo(grafo))
# Out:
# dfs desde A:
# A B D E F C
#  tiene ciclo:  True
